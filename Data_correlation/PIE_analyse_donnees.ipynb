# %%
from scipy.integrate import solve_ivp
from sklearn.linear_model import LinearRegression

import numpy as np

import netCDF4 as nc

from bokeh.io import  output_notebook, push_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import column, row
from bokeh.models import PrintfTickFormatter

from ipywidgets import interact, FloatSlider, IntSlider, Dropdown, FloatText

output_notebook(hide_banner=True)

import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
fn = 'Donnees/Donnees_PIE_Meteo.nc'
ds = nc.Dataset(fn)

# %%
print(ds)

# %%
for dim in ds.dimensions.values():
    print(dim)

# %%
plt.imshow(ds['GP_GDS0_PVL'][0,:,:])

# %%
fig = plt.figure(figsize=(8,5))
fig.imshow(ds['GP_GDS0_PVL'][0,:,:])

# %%
print(ds['GP_GDS0_PVL'][0,:,:])

# %%
nb=0  
if (nb==0) :
    donnee='GP_GDS0_PVL'
else :
    donnee='POT_GDS0_PVL'

ims=[]
for k in range(31):
    im = plt.imshow(ds[donnee][k,:,:], animated=True)
    ims.append([im])


fig=plt.figure()

anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

plt.show()

# %%
plt.imshow(ds['POT_GDS0_PVL'][0,:,:])

# %%
print(ds['initial_time0'])

# %%
print(ds['initial_time0_hours'])

# %%
print(ds['initial_time0_hours'][:])

# %%
ds['initial_time0']
